# %% [markdown]
# # Encoder-Decoder Models

# %% [markdown]
# ## References
#
# - [Encoder-Decoder Models and Transformers](https://medium.com/@gabell/encoder-decoder-models-and-transformers-5c1500c22c22)
